# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict, namedtuple


env = gym.make('Taxi-v3')
print(env.action_space)
print(env.observation_space)
n_states, n_actions = env.observation_space.n, env.action_space.n
# Out:
# Discrete(6)
# Discrete(500)

# %%
def TD_0(strategie, alpha, gamma):
    V = [(0)] * n_states
    for i_episode in range(1000):
        S = env.reset()
        for t in range(1000):
            #env.render()
            action = np.random.choice(np.arange(0, n_actions), p=strategie[S]) 
            S_prime, reward, done, info = env.step(action)
            #print(reward)
            if done and t != 200:
                V[S] += alpha * (reward - V[S])
                V[S_prime] = reward
            else:
                V[S] += alpha * (reward + gamma * V[S_prime] - V[S])
             
            S = S_prime
            if done:
                break
    return V

# %%
def epsilon_greedy(Q, epsilon, n_actions, S):
    A = np.ones(n_actions, dtype=float) * epsilon / n_actions
    best_action = np.argmax(Q[S])
    A[best_action] += (1.0 - epsilon)
    #print(A)
    return np.random.choice(np.arange(len(A)), p=A)

# %%
from IPython.display import clear_output
import time

def test_agent(Q):
    done = False
    S = env.reset()
    total = 0

    while not done:
        A = np.argmax(Q[S])
        S, reward, done, _ = env.step(A)
        total += reward
        time.sleep(0.5)
        clear_output(wait=True)
        env.render()
        print("Gain:", total)

# %%
def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / float(N)

# %%
def print_stats(rew):
    fig = plt.figure(figsize=(20, 5))
    ax1 = plt.subplot(121)
    ax1.title.set_text("Récompenses par épisode")
    plt.plot(rew, linewidth=1)
    ax2 = plt.subplot(122)
    ax2.title.set_text("Moyenne mobile (10 épisodes)")
    plt.plot(running_mean(rew, 10), linewidth=1)
    plt.show()

# %%
def SARSA(epsilon, alpha, gamma):
    rew = []
    Q = np.zeros((n_states, n_actions))
    for i_episode in range(1000):
        total_reward = 0
        S = env.reset()
        A = epsilon_greedy(Q, epsilon, n_actions, S)
        for t in range(20000):
            S_prime, reward, done, info = env.step(A)
            total_reward += reward
            
            A_prime = epsilon_greedy(Q, epsilon, n_actions, S_prime)
            
            Q[S][A] += alpha * (reward + gamma * Q[S_prime][A_prime] - Q[S][A])
            
            S = S_prime
            A = A_prime
            
            if done:
                rew.append(total_reward)
                break

    print("Récompense maximale:", np.max(rew))
    print_stats(rew)
    return Q

Q_S = SARSA(0.1, 0.5, 1)
# Out:
# Récompense maximale: 15

# %%
test_agent(Q_S)
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Gain: 4

# %%
def Q_learning(epsilon, alpha, gamma):
    rew = []
    Q = np.zeros((n_states, n_actions))
    for i_episode in range(1000):
        total_reward = 0
        S = env.reset()
        for t in range(20000):
            A = epsilon_greedy(Q, epsilon, n_actions, S)
            #A = env.action_space.sample()
            S_prime, reward, done, info = env.step(A)
            total_reward += reward
            
            if done and t != 200:
                Q[S][A] += alpha * (reward - Q[S][A])
            else:
                Q[S][A] += alpha * (reward + gamma * np.max(Q[S_prime]) - Q[S][A])
            S = S_prime
            
            if done:
                rew.append(total_reward)
                break
    print("Récompense maximale:", np.max(rew))
    print_stats(rew)
    return Q

Q_Q = Q_learning(0.1, 0.5, 0.9)
# Out:
# Récompense maximale: 15

# %%
test_agent(Q_Q)
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Gain: 11

# %% [markdown]
# # On policy vs off policy

# %%
Q_Q_rand = Q_learning(1, 0.5, 0.9)
# Out:
# Récompense maximale: -73

# %%
Q_S_rand = SARSA(1, 0.5, 0.9)
# Out:
# Récompense maximale: -57

# %%
test_agent(Q_S_rand)
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# Gain: -12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-a657ad9a3dde> in <module>
# ----> 1 test_agent(Q_S_rand)
#
# <ipython-input-4-ec3962d82df5> in test_agent(Q)
#      11         S, reward, done, _ = env.step(A)
#      12         total += reward
# ---> 13         time.sleep(0.5)
#      14         clear_output(wait=True)
#      15         env.render()
#
# KeyboardInterrupt:

# %%
test_agent(Q_Q_rand)
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# Gain: 6

# %% [markdown]
# # Retour sur TD(0)

# %%
def visualise_valeur_strategie(V, Q):
    done = False
    S = env.reset()
    total = 0

    while not done:
        A = np.argmax(Q_Q_rand[S])
        S, reward, done, _ = env.step(A)
        total += reward
        time.sleep(0.5)
        clear_output(wait=True)
        env.render()
        print("Valeur de l'état:", V[S])
        print("Gain:", total)

# %%
strategie = [[1/n_actions] * n_actions] * n_states
V = TD_0(strategie, 0.5, 0.9)

# %%
visualise_valeur_strategie(V, Q_Q_rand)
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 20
# Gain: 9

# %%
l_indices = np.argmax(Q_Q_rand, axis=1).tolist()
strat_optimale = []
for indice in l_indices:
    action = [(0)] * n_actions
    action[indice] = 1
    strat_optimale.append(action)

# %%
V_opti = TD_0(strat_optimale, 0.5, 0.9)
visualise_valeur_strategie(V_opti, Q_Q_rand)
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# 20
# Gain: 11
